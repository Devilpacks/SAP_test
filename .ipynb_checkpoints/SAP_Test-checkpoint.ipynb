# %% [markdown]
# # Задача: детекция инструментов в руках
# # Поскольку разрешено использование предобученных моделей будем использовать встроенные в Keras модели, обученные на датасете ImageNet, 1000 классов.
# # Проведем тестирование на рандомных фотографиях с яндекса.
# # Стоит заметить, что построение системы распознавания объектов на основе предобученных моделей

# %% [markdown]
# # Изобразим фотографии

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
from IPython.display import Image


img_path = 'hammer0.jpg'
display(Image(img_path, width=200, unconfined=True))

# %%
img_path = 'hammer1.jpg'
display(Image(img_path, width=200, unconfined=True))

# %%
img_path = 'hammer2.jpg'
display(Image(img_path, width=200, unconfined=True))

# %%
img_path = 'hammer3.jpg'
display(Image(img_path, width=200, unconfined=True))

# %%
img_path = 'hammer4.jpg'
display(Image(img_path, width=200, unconfined=True))

# %%
img_path = 'hammer5.jpg'
display(Image(img_path, width=200, unconfined=True))

# %%
img_path = 'hammer6.jpg'
display(Image(img_path, width=200, unconfined=True))

# %%
img_path = 'hammer7.jpg'
display(Image(img_path, width=200, unconfined=True))

# %% [markdown]
# #Будем выводить результат через встроенный API кераса, который дает наглядный результат, а точнее мы выводим отупут модели по первым трем самым вероятным классам определенных моделью.
#
#
# #Выводится все в данном формате: 'внутренний номер класса в ImageNet','наименование класса', вероятность присутствия класса на фото.

# %% [markdown]
# # VGG16

# %%
from keras import backend as K
from keras.models import Model
from keras.preprocessing import image
from keras.optimizers import SGD
from keras.applications.vgg16 import VGG16
from keras.applications.vgg16 import preprocess_input, decode_predictions


K.set_image_dim_ordering("th")
# Test pretrained model
model = VGG16(weights='imagenet', include_top=True)
optimizer = SGD()
model.compile(optimizer=optimizer, loss='categorical_crossentropy')
for i in range(0,7):
    img_path = 'hammer'+ str(i)+'.jpg'
    img = image.load_img(img_path, target_size=(224, 224))
    
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    
    preds = model.predict(x)
    print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# /home/barrel/anaconda2/lib/python2.7/site-packages/keras/applications/vgg16.py:188: UserWarning: You are using the TensorFlow backend, yet you are using the Theano image data format convention (`image_data_format="channels_first"`). For best performance, set `image_data_format="channels_last"` in your Keras config at ~/.keras/keras.json.
#   warnings.warn('You are using the TensorFlow backend, yet you '
# ('Predicted:', [(u'n03481172', u'hammer', 0.48248473), (u'n03498962', u'hatchet', 0.38972473), (u'n03804744', u'nail', 0.040642288)])
# ('Predicted:', [(u'n09835506', u'ballplayer', 0.30259055), (u'n04357314', u'sunscreen', 0.08732719), (u'n04090263', u'rifle', 0.06443136)])
# ('Predicted:', [(u'n03467068', u'guillotine', 0.71925586), (u'n03742115', u'medicine_chest', 0.12916619), (u'n03970156', u'plunger', 0.023998022)])
# ('Predicted:', [(u'n02787622', u'banjo', 0.55269384), (u'n04597913', u'wooden_spoon', 0.065278545), (u'n03970156', u'plunger', 0.061665364)])
# ...

# %% [markdown]
# # ResNet50

# %%
from keras.applications.resnet50 import ResNet50
from keras.preprocessing import image
from keras.applications.resnet50 import preprocess_input, decode_predictions

model = ResNet50(weights='imagenet')

for i in range(0,7):
    img_path = 'hammer'+ str(i)+'.jpg'
    img = image.load_img(img_path, target_size=(224, 224))
    
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    
    preds = model.predict(x)
    print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# ('Predicted:', [(u'n03255030', u'dumbbell', 0.3204783), (u'n03481172', u'hammer', 0.26144406), (u'n03498962', u'hatchet', 0.24766982)])
# ('Predicted:', [(u'n03188531', u'diaper', 0.4361133), (u'n02837789', u'bikini', 0.087381095), (u'n04371430', u'swimming_trunks', 0.08407154)])
# ('Predicted:', [(u'n03481172', u'hammer', 0.37703374), (u'n03970156', u'plunger', 0.370668), (u'n03633091', u'ladle', 0.036442522)])
# ('Predicted:', [(u'n04597913', u'wooden_spoon', 0.25326562), (u'n02906734', u'broom', 0.08884924), (u'n03721384', u'marimba', 0.060255043)])
# ('Predicted:', [(u'n02783161', u'ballpoint', 0.0835625), (u'n04141327', u'scabbard', 0.059756115), (u'n03876231', u'paintbrush', 0.05166361)])
# ('Predicted:', [(u'n03498962', u'hatchet', 0.45967415), (u'n03481172', u'hammer', 0.4213905), (u'n04118776', u'rule', 0.021774692)])
# ('Predicted:', [(u'n03481172', u'hammer', 0.96033895), (u'n03498962', u'hatchet', 0.03509275), (u'n04192698', u'shield', 0.0027252943)])

# %% [markdown]
# # VGG19

# %%
from keras.applications.vgg19 import VGG19
from keras.preprocessing import image
from keras.applications.vgg19 import preprocess_input, decode_predictions
from keras.models import Model


model = VGG19(weights='imagenet')

for i in range(0,7):
    img_path = 'hammer'+ str(i)+'.jpg'
    img = image.load_img(img_path, target_size=(224, 224))
    
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    
    preds = model.predict(x)
    print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# ('Predicted:', [(u'n03970156', u'plunger', 0.4702303), (u'n03481172', u'hammer', 0.23130994), (u'n03498962', u'hatchet', 0.0867994)])
# ('Predicted:', [(u'n09835506', u'ballplayer', 0.28672197), (u'n02799071', u'baseball', 0.19646534), (u'n04090263', u'rifle', 0.08216043)])
# ('Predicted:', [(u'n04443257', u'tobacco_shop', 0.35022855), (u'n03742115', u'medicine_chest', 0.09330142), (u'n03970156', u'plunger', 0.07096164)])
# ('Predicted:', [(u'n03633091', u'ladle', 0.32193056), (u'n03721384', u'marimba', 0.16666898), (u'n03970156', u'plunger', 0.055595946)])
# ('Predicted:', [(u'n04154565', u'screwdriver', 0.17930447), (u'n04376876', u'syringe', 0.04807359), (u'n04517823', u'vacuum', 0.04633251)])
# ('Predicted:', [(u'n03481172', u'hammer', 0.47541746), (u'n03498962', u'hatchet', 0.26695094), (u'n03041632', u'cleaver', 0.047738723)])
# ('Predicted:', [(u'n03481172', u'hammer', 0.4122245), (u'n09835506', u'ballplayer', 0.16315204), (u'n03873416', u'paddle', 0.07675657)])

# %% [markdown]
# # InceptionV3

# %%
from keras.applications.inception_v3 import InceptionV3
from keras.preprocessing import image
from keras.applications.inception_v3 import preprocess_input, decode_predictions
from keras.models import Model


model = InceptionV3(weights='imagenet')
for i in range(0,7):
    img_path = 'hammer'+ str(i)+'.jpg'
    img = image.load_img(img_path, target_size=(299, 299))
    
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    
    preds = model.predict(x)
    print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# ('Predicted:', [(u'n03481172', u'hammer', 0.6848786), (u'n03498962', u'hatchet', 0.07222038), (u'n02787622', u'banjo', 0.036714014)])
# ('Predicted:', [(u'n03481172', u'hammer', 0.13736778), (u'n04067472', u'reel', 0.11420551), (u'n03498962', u'hatchet', 0.064876996)])
# ('Predicted:', [(u'n03481172', u'hammer', 0.9536136), (u'n03742115', u'medicine_chest', 0.009333184), (u'n03498962', u'hatchet', 0.007735202)])
# ('Predicted:', [(u'n03970156', u'plunger', 0.5228212), (u'n03062245', u'cocktail_shaker', 0.023291841), (u'n02906734', u'broom', 0.02206583)])
# ('Predicted:', [(u'n02783161', u'ballpoint', 0.29824758), (u'n03908618', u'pencil_box', 0.24465886), (u'n04154565', u'screwdriver', 0.052382555)])
# ('Predicted:', [(u'n03481172', u'hammer', 0.985649), (u'n03804744', u'nail', 0.0035729106), (u'n03498962', u'hatchet', 0.0029423952)])
# ('Predicted:', [(u'n03481172', u'hammer', 0.73010904), (u'n03804744', u'nail', 0.06670164), (u'n03498962', u'hatchet', 0.06583106)])

# %% [markdown]
# # InceptionResNetV2

# %%
from keras.applications.inception_resnet_v2 import InceptionResNetV2
from keras.preprocessing import image
from keras.applications.inception_resnet_v2 import preprocess_input, decode_predictions
from keras.models import Model


model = InceptionResNetV2(weights='imagenet')
for i in range(0,7):
    img_path = 'hammer'+ str(i)+'.jpg'
    img = image.load_img(img_path, target_size=(299, 299))
    
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    
    preds = model.predict(x)
    print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# ('Predicted:', [(u'n03481172', u'hammer', 0.9912566), (u'n03255030', u'dumbbell', 0.001929902), (u'n03498962', u'hatchet', 0.0014773313)])
# ('Predicted:', [(u'n03481172', u'hammer', 0.9858046), (u'n03498962', u'hatchet', 0.010205165), (u'n03804744', u'nail', 0.00032847055)])
# ('Predicted:', [(u'n03481172', u'hammer', 0.9516847), (u'n03804744', u'nail', 0.0056508565), (u'n03498962', u'hatchet', 0.003018503)])
# ('Predicted:', [(u'n02787622', u'banjo', 0.3776954), (u'n04238763', u'slide_rule', 0.28658855), (u'n04597913', u'wooden_spoon', 0.024198048)])
# ('Predicted:', [(u'n03481172', u'hammer', 0.5089577), (u'n02783161', u'ballpoint', 0.05862518), (u'n04154565', u'screwdriver', 0.04053848)])
# ('Predicted:', [(u'n03481172', u'hammer', 0.9170295), (u'n03804744', u'nail', 0.0143496385), (u'n03498962', u'hatchet', 0.012085935)])
# ('Predicted:', [(u'n03481172', u'hammer', 0.8184067), (u'n03804744', u'nail', 0.022030216), (u'n09835506', u'ballplayer', 0.011237649)])

# %% [markdown]
# # В итоге, более глубокая архитектура InceptionResNetV2, распознала 7 из 7 молотков!
